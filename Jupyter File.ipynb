# %% [markdown]
# ## Train.py Script

# %%
# Run the train.py script
# %run data_generation.py

# %% [markdown]
# ## Test.py Script

# %%
# Run the train.py script
# %run train.py
# Out:
# WARNING:tensorflow:From C:\Users\Eysteinn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Train: 1803/1803 - Valid: 600/600 - Test: 600/600
#
# WARNING:tensorflow:From C:\Users\Eysteinn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# ...

# %%
# Run the test.py script
# %run test.py
# Out:
# Train: 1803/1803 - Valid: 600/600 - Test: 600/600
# 100%|██████████| 600/600 [03:04<00:00,  3.26it/s]
# Class           F1         Jaccard
# -----------------------------------
# hood           : 0.00010 - 0.00005
# front door     : 0.00709 - 0.00371
# rear door      : 0.00000 - 0.00000
# frame          : 0.01484 - 0.00769
# rear quater panel: 0.00583 - 0.00326
# trunk lid      : 0.00000 - 0.00000
# fender         : 0.00000 - 0.00000
# bumper         : 0.00000 - 0.00000
# rest of car    : 0.95636 - 0.91779
# -----------------------------------
# Mean           : 0.10936 - 0.10361
