# %% [markdown]
# ## Train.py Script

# %%
# Run the train.py script
# %run data_generation.py

# %% [markdown]
# ## Test.py Script

# %%
# Run the train.py script
# %run train.py
# Out:
# Train: 1803/1803 - Valid: 600/600 - Test: 600/600
#
# WARNING:tensorflow:From C:\Users\Eysteinn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Eysteinn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), name='emau/Relu_1:0', description="created by layer 'emau'")
# Model: "U-Net_with_EMU"
# __________________________________________________________________________________________________
# ...

# %%
# Run the test.py script
# %run test.py
# Out:
# WARNING:tensorflow:From C:\Users\Eysteinn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\Downloads\COMBINE FILES INTO JU\test.py:71
#      69 """ Model """
#      70 # model = tf.keras.models.load_model(model_path)
# ---> 71 model = tf.keras.models.load_model(model_path, custom_objects={'EMAU':EMAU})
#      72 """ Load the dataset """
#      73 (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset()
#
# ...
